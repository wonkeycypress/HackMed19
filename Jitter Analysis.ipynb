# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
healthy_df = pd.read_csv('healthy.csv', delimiter=",")

# %%
parkinsons_df = pd.read_csv('parkinsons.csv', delimiter=",")

# %%
sns.kdeplot(healthy_df['jitter_local'], shade=True, label="Healthy")
sns.kdeplot(parkinsons_df['jitter_local'], shade=True, label="Parksinson's")
sns.boxplot(data=healthy['jitter_local', x='label', y='value')


plt.legend()
plt.show()

# %%
sns.kdeplot(healthy_df['jitter_rap'], shade=True, label="Healthy")
sns.kdeplot(parkinsons_df['jitter_rap'], shade=True, label="Parksinson's")


plt.legend()
plt.show()

# %%
sns.kdeplot(healthy_df['jitter_ppq5'], shade=True, label="Healthy")
sns.kdeplot(parkinsons_df['jitter_ppq5'], shade=True, label="Parksinson's")


plt.legend()
plt.show()

# %%
sns.kdeplot(healthy_df['jitter_ddp'], shade=True, label="Healthy")
sns.kdeplot(parkinsons_df['jitter_ddp'], shade=True, label="Parksinson's")


plt.legend()
plt.show()
